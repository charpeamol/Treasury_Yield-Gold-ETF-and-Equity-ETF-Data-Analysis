# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
from matplotlib import *
import quandl
from pylab import rcParams # sizing 
rcParams['figure.figsize'] = 15, 15
import yfinance as yf

# %% [markdown]
# # Importing Shares Gold Trust (IAU) data for analysis purpose  from March 2020 to Dec 2020

# %%
#Shares Gold Trust (IAU) download required data for analysis purpose  from March 2020 to Dec 2020
gold_etf=yf.download("IAU",start="2020-03-01",end="2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gold_etf
# Out:
#                  Open       High    Low      Close  Adj Close    Volume
# Date
# 2020-03-02  15.220000  15.300000  15.13  15.150000  15.150000  35438900
# 2020-03-03  15.320000  15.760000  15.30  15.620000  15.620000  55830000
# 2020-03-04  15.680000  15.740000  15.60  15.660000  15.660000  29541000
# 2020-03-05  15.830000  16.000000  15.81  15.990000  15.990000  28626400
# 2020-03-06  16.080000  16.170000  15.69  16.000000  16.000000  35645700
# ...               ...        ...    ...        ...        ...       ...
# 2020-12-24  17.860001  17.930000  17.84  17.920000  17.920000   7495900
# 2020-12-28  18.010000  18.080000  17.85  17.870001  17.870001  16733000
# 2020-12-29  17.910000  17.990000  17.85  17.910000  17.910000  16025000
# 2020-12-30  17.940001  18.059999  17.93  18.049999  18.049999  13599000
# 2020-12-31  18.100000  18.129999  18.02  18.129999  18.129999  12471800
#
# [213 rows x 6 columns]

# %% [markdown]
# # kotal mahindra it is indian private sector bank we are Importing Kotak Nifty Exchange Traded Scheme for analysis purpose from from March 2020 to Dec 2020

# %%
# kotal mahindra it is indian private sector bank we are using Kotak Nifty Exchange Traded Scheme for analysis purpose from from March 2020 to Dec 2020 
equity_etf=yf.download("KOTAKNIFTY.NS",start="2020-03-01",end="2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
equity_etf
# Out:
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2020-03-02  118.279999  118.589996  116.230003  116.790001  116.790001  117149
# 2020-03-03  119.099998  121.500000  116.150002  117.430000  117.430000   56436
# 2020-03-04  117.339996  117.779999  115.500000  116.870003  116.870003   56076
# 2020-03-05  119.199997  119.199997  116.930000  117.129997  117.129997   32413
# 2020-03-06  119.500000  121.800003  112.599998  114.830002  114.830002  215819
# ...                ...         ...         ...         ...         ...     ...
# 2020-12-24  142.000000  143.660004  142.000000  143.419998  143.419998   27106
# 2020-12-28  143.250000  145.000000  143.000000  144.429993  144.429993  113262
# 2020-12-29  144.899994  146.050003  144.330002  144.910004  144.910004   85076
# 2020-12-30  145.990005  146.000000  144.360001  145.589996  145.589996   62498
# 2020-12-31  145.029999  146.000000  145.029999  145.649994  145.649994   15235
#
# ...

# %% [markdown]
# # Importing  BTC usd bitcoin data from From  March 2020 to December 2020

# %%
 
bitcoin=yf.download("BTC-USD",start="2020-03-02",end="2021-01-01")
bitcoin
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2020-03-01   8599.758789   8726.796875   8471.212891   8562.454102
# 2020-03-02   8563.264648   8921.308594   8532.630859   8869.669922
# 2020-03-03   8865.387695   8901.598633   8704.990234   8787.786133
# 2020-03-04   8788.541992   8843.366211   8712.431641   8755.246094
# 2020-03-05   8760.285156   9142.054688   8757.253906   9078.762695
# ...                  ...           ...           ...           ...
# 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#                Adj Close       Volume
# Date
# 2020-03-01   8562.454102  35349164300
# ...

# %% [markdown]
# # Data Processing

# %% [markdown]
# # daily returns for gold_etf represted in new column in dataframe  ie Daily Returns

# %%
gold_etf=gold_etf.assign(
Daily_Returns=gold_etf.Close.pct_change() * 100
)
gold_etf
# Out:
#                  Open       High    Low      Close  Adj Close    Volume  \
# Date
# 2020-03-02  15.220000  15.300000  15.13  15.150000  15.150000  35438900
# 2020-03-03  15.320000  15.760000  15.30  15.620000  15.620000  55830000
# 2020-03-04  15.680000  15.740000  15.60  15.660000  15.660000  29541000
# 2020-03-05  15.830000  16.000000  15.81  15.990000  15.990000  28626400
# 2020-03-06  16.080000  16.170000  15.69  16.000000  16.000000  35645700
# ...               ...        ...    ...        ...        ...       ...
# 2020-12-24  17.860001  17.930000  17.84  17.920000  17.920000   7495900
# 2020-12-28  18.010000  18.080000  17.85  17.870001  17.870001  16733000
# 2020-12-29  17.910000  17.990000  17.85  17.910000  17.910000  16025000
# 2020-12-30  17.940001  18.059999  17.93  18.049999  18.049999  13599000
# 2020-12-31  18.100000  18.129999  18.02  18.129999  18.129999  12471800
#
#             Daily_Returns
# Date
# 2020-03-02            NaN
# 2020-03-03       3.102312
# ...

# %%
gold_etf=gold_etf[gold_etf.index>="2020-03-03"] # dropping NAN th   data 
gold_etf
# Out:
#                  Open       High    Low      Close  Adj Close    Volume  \
# Date
# 2020-03-03  15.320000  15.760000  15.30  15.620000  15.620000  55830000
# 2020-03-04  15.680000  15.740000  15.60  15.660000  15.660000  29541000
# 2020-03-05  15.830000  16.000000  15.81  15.990000  15.990000  28626400
# 2020-03-06  16.080000  16.170000  15.69  16.000000  16.000000  35645700
# 2020-03-09  16.090000  16.150000  15.88  16.040001  16.040001  38619500
# ...               ...        ...    ...        ...        ...       ...
# 2020-12-24  17.860001  17.930000  17.84  17.920000  17.920000   7495900
# 2020-12-28  18.010000  18.080000  17.85  17.870001  17.870001  16733000
# 2020-12-29  17.910000  17.990000  17.85  17.910000  17.910000  16025000
# 2020-12-30  17.940001  18.059999  17.93  18.049999  18.049999  13599000
# 2020-12-31  18.100000  18.129999  18.02  18.129999  18.129999  12471800
#
#             Daily_Returns
# Date
# 2020-03-03       3.102312
# 2020-03-04       0.256082
# ...

# %% [markdown]
# # daily returns for Equity_ETF represted in new column in dataframe ie Daily Returns

# %%
equity_etf=equity_etf.assign(
Daily_Returns=equity_etf.Close.pct_change() * 100
)
equity_etf
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-03-02  118.279999  118.589996  116.230003  116.790001  116.790001
# 2020-03-03  119.099998  121.500000  116.150002  117.430000  117.430000
# 2020-03-04  117.339996  117.779999  115.500000  116.870003  116.870003
# 2020-03-05  119.199997  119.199997  116.930000  117.129997  117.129997
# 2020-03-06  119.500000  121.800003  112.599998  114.830002  114.830002
# ...                ...         ...         ...         ...         ...
# 2020-12-24  142.000000  143.660004  142.000000  143.419998  143.419998
# 2020-12-28  143.250000  145.000000  143.000000  144.429993  144.429993
# 2020-12-29  144.899994  146.050003  144.330002  144.910004  144.910004
# 2020-12-30  145.990005  146.000000  144.360001  145.589996  145.589996
# 2020-12-31  145.029999  146.000000  145.029999  145.649994  145.649994
#
#             Volume  Daily_Returns
# Date
# 2020-03-02  117149            NaN
# ...

# %%
equity_etf=equity_etf[equity_etf.index>="2020-03-03"] # dropping NAN data
equity_etf
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-03-03  119.099998  121.500000  116.150002  117.430000  117.430000
# 2020-03-04  117.339996  117.779999  115.500000  116.870003  116.870003
# 2020-03-05  119.199997  119.199997  116.930000  117.129997  117.129997
# 2020-03-06  119.500000  121.800003  112.599998  114.830002  114.830002
# 2020-03-09  117.099998  119.400002  108.099998  109.949997  109.949997
# ...                ...         ...         ...         ...         ...
# 2020-12-24  142.000000  143.660004  142.000000  143.419998  143.419998
# 2020-12-28  143.250000  145.000000  143.000000  144.429993  144.429993
# 2020-12-29  144.899994  146.050003  144.330002  144.910004  144.910004
# 2020-12-30  145.990005  146.000000  144.360001  145.589996  145.589996
# 2020-12-31  145.029999  146.000000  145.029999  145.649994  145.649994
#
#             Volume  Daily_Returns
# Date
# 2020-03-03   56436       0.547992
# ...

# %% [markdown]
# # daily returns for Bitcoin represted in new column in dataframe ie Daily Returns

# %%
# BTICOIN daily returns
bitcoin=bitcoin.assign(
Daily_Returns=bitcoin.
    Close.pct_change() * 100
)
bitcoin
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-03-01   8599.758789   8726.796875   8471.212891   8562.454102
# 2020-03-02   8563.264648   8921.308594   8532.630859   8869.669922
# 2020-03-03   8865.387695   8901.598633   8704.990234   8787.786133
# 2020-03-04   8788.541992   8843.366211   8712.431641   8755.246094
# 2020-03-05   8760.285156   9142.054688   8757.253906   9078.762695
# ...                  ...           ...           ...           ...
# 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#                Adj Close       Volume  Daily_Returns
# Date
# 2020-03-01   8562.454102  35349164300            NaN
# ...

# %%
bitcoin=bitcoin[bitcoin.index>="2020-03-03"] # dropping NAN data

# %%
bitcoin
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-03-03   8865.387695   8901.598633   8704.990234   8787.786133
# 2020-03-04   8788.541992   8843.366211   8712.431641   8755.246094
# 2020-03-05   8760.285156   9142.054688   8757.253906   9078.762695
# 2020-03-06   9078.308594   9167.695312   9032.079102   9122.545898
# 2020-03-07   9121.600586   9163.220703   8890.744141   8909.954102
# ...                  ...           ...           ...           ...
# 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#                Adj Close       Volume  Daily_Returns
# Date
# 2020-03-03   8787.786133  42386715820      -0.923189
# ...

# %% [markdown]
# # Data summaries

# %% [markdown]
# # Compute a 20-day moving average price of your GOLD ETF.  The moving average price on 1 April 2020 should include data from March.

# %% [markdown]
# # GOLD_ETF

# %%
window=20
gold_etf=gold_etf.assign(
Moving_Avg_20_Day=gold_etf.Close.rolling(window).mean()
)

# %%
gold_etf=gold_etf[gold_etf.index>="2020-04-01"] # cinsidering data from  April
gold_etf
# Out:
#                  Open       High    Low      Close  Adj Close    Volume  \
# Date
# 2020-04-01  15.070000  15.240000  15.01  15.170000  15.170000  26372200
# 2020-04-02  15.390000  15.490000  15.30  15.420000  15.420000  19759000
# 2020-04-03  15.470000  15.550000  15.40  15.530000  15.530000  19140500
# 2020-04-06  15.660000  15.970000  15.63  15.940000  15.940000  25033500
# 2020-04-07  15.780000  15.880000  15.68  15.880000  15.880000  27516700
# ...               ...        ...    ...        ...        ...       ...
# 2020-12-24  17.860001  17.930000  17.84  17.920000  17.920000   7495900
# 2020-12-28  18.010000  18.080000  17.85  17.870001  17.870001  16733000
# 2020-12-29  17.910000  17.990000  17.85  17.910000  17.910000  16025000
# 2020-12-30  17.940001  18.059999  17.93  18.049999  18.049999  13599000
# 2020-12-31  18.100000  18.129999  18.02  18.129999  18.129999  12471800
#
#             Daily_Returns  Moving_Avg_20_Day
# Date
# ...

# %% [markdown]
# # Compute a 20-day moving average price of your equity ETF.  The moving average price on 1 April 2020 should include data from March.

# %%
window=20
equity_etf=equity_etf.assign(
Moving_Avg_20_Day=equity_etf.Close.rolling(window).mean()
)
equity_etf=equity_etf[equity_etf.index>="2020-04-01"] # dropping 30 th september  data 
equity_etf
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-04-01   88.500000   90.000000   86.199997   86.720001   86.720001
# 2020-04-03   86.720001   87.440002   84.000000   84.580002   84.580002
# 2020-04-07   87.989998   90.949997   86.000000   90.660004   90.660004
# 2020-04-08   90.500000   94.379997   88.809998   91.019997   91.019997
# 2020-04-09   93.800003   94.199997   91.500000   93.580002   93.580002
# ...                ...         ...         ...         ...         ...
# 2020-12-24  142.000000  143.660004  142.000000  143.419998  143.419998
# 2020-12-28  143.250000  145.000000  143.000000  144.429993  144.429993
# 2020-12-29  144.899994  146.050003  144.330002  144.910004  144.910004
# 2020-12-30  145.990005  146.000000  144.360001  145.589996  145.589996
# 2020-12-31  145.029999  146.000000  145.029999  145.649994  145.649994
#
#             Volume  Daily_Returns  Moving_Avg_20_Day
# Date
# ...

# %% [markdown]
# # Compute a 20-day moving average price of bitcoin.  The moving average price on 1 April 2020 should include data from March.

# %%
bitcoin=bitcoin.assign(
Moving_Avg_20_Day=bitcoin.Close.rolling(window).mean()
)
bitcoin=bitcoin[bitcoin.index>="2020-04-01"] # dropping 30 th september  data 
bitcoin
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-04-01   6437.319336   6612.573730   6202.373535   6606.776367
# 2020-04-02   6606.776367   7088.247559   6595.918457   6793.624512
# 2020-04-03   6797.396484   7003.220703   6673.335938   6733.387207
# 2020-04-04   6738.382812   6878.953613   6696.484863   6867.527344
# 2020-04-05   6862.537598   6883.414062   6715.929199   6791.129395
# ...                  ...           ...           ...           ...
# 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#                Adj Close       Volume  Daily_Returns  Moving_Avg_20_Day
# Date
# 2020-04-01   6606.776367  40346426265       2.611292        6034.907422
# ...

# %%
plt.rc('xtick', labelsize=15) 
plt.rc('ytick', labelsize=15)

# %% [markdown]
# # Graphing

# %% [markdown]
# # 4.1Graph each price series along with its moving average from April 2020 through Dec 2020.

# %% [markdown]
# # 1)gold_etf

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(gold_etf.index, gold_etf.Close)
ax1.set_ylabel('Close Price of Gold_etf')

ax2 = ax1.twinx()
ax2.plot(gold_etf.index,gold_etf.Moving_Avg_20_Day, 'r-')
ax2.set_ylabel('Moving avg 20 day Close Price of gold_etf', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# %% [markdown]
# # 2)equity_etf

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(equity_etf.index, equity_etf.Close)
ax1.set_ylabel('Close Price of equity_etf')

ax2 = ax1.twinx()
ax2.plot(equity_etf.index,equity_etf.Moving_Avg_20_Day, 'r-')
ax2.set_ylabel('Moving avg 20 day Close Price of equity_etf', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# %% [markdown]
# # 3)bitcoin

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(bitcoin.index, bitcoin.Close)
ax1.set_ylabel('Close Price of bitcoin')

ax2 = ax1.twinx()
ax2.plot(bitcoin.index,bitcoin.Moving_Avg_20_Day, 'r-')
ax2.set_ylabel('Moving avg 20 day Close Price of bitcoin', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# %% [markdown]
# # Comments on how the price series and average series intersect or not.

# %% [markdown]
# Gold_ETF: for gold_etf 20 day moving avg line interest the daily price of Gold_ETF .from April to Auguest looks volatile.             it can be clearly seen that after auguest 2020 moving avg line act like resistance line to gold_etf prices
#
# Equity_ETF: for equity_etf 20 day moving avg line interest the daily price of Gold_ETF
#              when there is sudden plunged in stock in the month of octomber.it can be clearly seen that except octomber                 Month moving avg line act like support  line to Equity_ETF prices .
#
# Bitcoin:    for Bitcoin 20 day moving avg line  does not interest the daily price of Bitcoin .for entire duration moving avg         line act like resistance line

# %% [markdown]
# # Graph gold and equity prices on the same plot.  Use a separate scale for each series, and be sure to add a label and legend

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(gold_etf.index, gold_etf.Close)
ax1.set_ylabel('Close Price of gold_etf')

ax2 = ax1.twinx()
ax2.plot(equity_etf.index,equity_etf.Close, 'r-')
ax2.set_ylabel(' Close Price of equity_etf', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# %% [markdown]
# # Graph gold and bitcoin prices on the same plot.  Use a separate scale for each series, and be sure to add a label and legend

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(gold_etf.index, gold_etf.Close)
ax1.set_ylabel('Close Price of gold_etf')

ax2 = ax1.twinx()
ax2.plot(bitcoin.index,bitcoin.Close, 'r-')
ax2.set_ylabel(' Close Price of bitcoin', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# %% [markdown]
# # Graph equity and bitcoin prices on the same plot.  Use a separate scale for each series, and be sure to add a label and legend

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(equity_etf.index, equity_etf.Close)
ax1.set_ylabel('Close Price of equity_etf')

ax2 = ax1.twinx()
ax2.plot(bitcoin.index,bitcoin.Close, 'r-')
ax2.set_ylabel(' Close Price of bitcoin', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# %% [markdown]
# # Fitting GARCH model

# %% [markdown]
# # Pick one of the 3 series (gold, equity, or bitcoin).  Fit a GARCH model for period April - December

# %% [markdown]
# # equity_etf

# %%
from arch import arch_model

model = arch_model(equity_etf.Daily_Returns, mean='Zero', vol='GARCH', p=1, o=0, q=1)

# %%
model_fit = model.fit(disp='off')

print(model_fit.summary())
# Out:
#                        Zero Mean - GARCH Model Results
# ...
# Dep. Variable:          Daily_Returns   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.006
# Vol Model:                      GARCH   Log-Likelihood:               -284.897
# Distribution:                  Normal   AIC:                           575.794
# Method:            Maximum Likelihood   BIC:                           585.389
#                                         No. Observations:                  181
# Date:                Tue, Jan 26 2021   Df Residuals:                      178
# Time:                        18:09:37   Df Model:                            3
#                                Volatility Model
# ...
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0377  2.034e-02      1.852  6.401e-02 [-2.194e-03,7.755e-02]
# ...

# %%
long_term_variance_garch=(model_fit.params[0])/(1-(model_fit.params[1])-(model_fit.params[2]))

# %%
long_term_variance_garch
# Out:
# 0.9149807908926599

# %%
model_fit.plot()

# %% [markdown]
# # Repeat the process, but instead using GARCH-M Model

# %%
garch_mean = arch_model(equity_etf.Daily_Returns, mean = "Constant", vol = "GARCH", p = 1, q = 1)
garch_mean_fit= garch_mean.fit(update_freq = 5)
garch_mean_fit.summary()
# Out:
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 297.9795843236335
# Iteration:     10,   Func. Count:     64,   Neg. LLF: 279.49193136102485
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 279.49157117494883
#             Iterations: 13
#             Function evaluations: 79
#             Gradient evaluations: 13
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:          Daily_Returns   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                      GARCH   Log-Likelihood:               -279.492
# Distribution:                  Normal   AIC:                           566.983
# Method:            Maximum Likelihood   BIC:                           579.777
#                                         No. Observations:                  181
# ...

# %%
long_term_variance_mean_garch=(garch_mean_fit.params[1])/(1-(garch_mean_fit.params[2])-(garch_mean_fit.params[3]))

# %%
long_term_variance_mean_garch
# Out:
# 0.8527964887899443

# %%
garch_mean_fit.plot()

# %% [markdown]
# # Implement Threshold GARCH, Exponential GARCH and Integrated GARCH

# %% [markdown]
# # THreshold or GJR GARCH

# %%
T_model= arch_model(equity_etf.Daily_Returns, p=1, o=1, q=1)
T_model_fit= T_model.fit(update_freq=5, disp='off')
print(T_model_fit.summary())
# Out:
#                    Constant Mean - GJR-GARCH Model Results
# ...
# Dep. Variable:          Daily_Returns   R-squared:                      -0.000
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.000
# Vol Model:                  GJR-GARCH   Log-Likelihood:               -279.492
# Distribution:                  Normal   AIC:                           568.983
# Method:            Maximum Likelihood   BIC:                           584.976
#                                         No. Observations:                  181
# Date:                Tue, Jan 26 2021   Df Residuals:                      176
# Time:                        18:10:12   Df Model:                            5
#                                Mean Model
# ...
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             0.2655  7.362e-02      3.606  3.114e-04 [  0.121,  0.410]
# ...

# %%
long_term_variance_T_Model=(T_model_fit.params[1])/(1-(T_model_fit.params[2])-(T_model_fit.params[4]))

# %%
long_term_variance_T_Model
# Out:
# 0.8527689343098346

# %%
T_model_fit.plot()

# %% [markdown]
# # Exponential GARCH

# %%
E_model=arch_model(equity_etf.Daily_Returns, p = 1, q = 1, o = 1,mean = 'zero', vol = 'EGARCH')
E_model_fit = E_model.fit(disp='off')
print(E_model_fit.summary())
# Out:
#                        Zero Mean - EGARCH Model Results
# ...
# Dep. Variable:          Daily_Returns   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.006
# Vol Model:                     EGARCH   Log-Likelihood:               -278.858
# Distribution:                  Normal   AIC:                           565.715
# Method:            Maximum Likelihood   BIC:                           578.509
#                                         No. Observations:                  181
# Date:                Tue, Jan 26 2021   Df Residuals:                      177
# Time:                        18:10:34   Df Model:                            4
#                                Volatility Model
# ...
#                  coef    std err          t      P>|t|        95.0% Conf. Int.
# ------------------------------------------------------------------------------
# omega      8.2017e-04  1.611e-09  5.092e+05      0.000   [8.202e-04,8.202e-04]
# ...

# %%
long_term_variance_E_Model=(E_model_fit.params[0])/(1-(E_model_fit.params[1])-(E_model_fit.params[3]))

# %%
long_term_variance_E_Model
# Out:
# 0.005705105895562421

# %%
E_model_fit.plot()

# %% [markdown]
# # Integrated GARCH

# %%
integrated_model=arch_model(equity_etf.Daily_Returns, p = 1, q = 1, power = 1.0, vol = 'FIGARCH')
integrated_model= integrated_model.fit(disp='off')
print(integrated_model.summary())
# Out:
#                     Constant Mean - FIGARCH Model Results
# ...
# Dep. Variable:          Daily_Returns   R-squared:                      -0.001
# Mean Model:             Constant Mean   Adj. R-squared:                 -0.001
# Vol Model:                    FIGARCH   Log-Likelihood:               -286.136
# Distribution:                  Normal   AIC:                           582.272
# Method:            Maximum Likelihood   BIC:                           598.264
#                                         No. Observations:                  181
# Date:                Tue, Jan 26 2021   Df Residuals:                      176
# Time:                        18:11:00   Df Model:                            5
#                                 Mean Model
# ...
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# mu             0.2426  7.901e-02      3.070  2.140e-03 [8.771e-02,  0.397]
# ...

# %%
integrated_model.plot()

# %% [markdown]
# # Q)What are the 3 long-term variances indicated by the models.

# %% [markdown]
# we can calculate weigh assinged to long term variance as  γ = 1 –α – β and  The long-term variance can then be calculated as ω/γ
#
# ....GARCH(1,1)-> long term variance=0.9149.........
#
# ....Threshold GARCH-> long term variance=0.8527...................................
#
# ....EGARCH-> long term variance=0.99...........................................
# ...............................................................................

# %% [markdown]
# # Assesing Stationary

# %% [markdown]
# we are using  Augmented Dickey–Fuller test to check stationary of all 3 series
# augmented Dickey–Fuller test (ADF) tests the null hypothesis that a unit root is present in a time series sample
# H0: Time Series is not stationary
# H1:time series is stationary

# %% [markdown]
# # Checking stationarity of gold etf

# %%
from statsmodels.tsa.stattools import adfuller, kpss
def adf_stationarity_test(price):
    indices= ['Test Statistic', 'p-value','no of Lags Used', 'no of Observations Used']
    adf_sta_test=adfuller(price,autolag="AIC")
    print(adf_sta_test)
    result=pd.Series(adf_sta_test[0:4],index=indices)
    for key,value in adf_sta_test[4].items():
        print(key)
        print(value)
        result[f'Critical value({key})']=value
    
    return result
adf_stationarity_test(gold_etf.Close)
# Out:
# (-2.48068822206482, 0.12024407138395332, 0, 190, {'1%': -3.4652439354133255, '5%': -2.8768752281673717, '10%': -2.574944653739612}, -76.04328558982462)
# 1%
# -3.4652439354133255
# 5%
# -2.8768752281673717
# 10%
# -2.574944653739612
# Test Statistic              -2.480688
# p-value                      0.120244
# no of Lags Used              0.000000
# no of Observations Used    190.000000
# Critical value(1%)          -3.465244
# Critical value(5%)          -2.876875
# Critical value(10%)         -2.574945
# dtype: float64

# %% [markdown]
# the null hypothesis of the Augmented Duckey Fuller  test states that the time series is not stationary.
# p value is 12% greater than 5% hence fail to reject null hypothesis hence time series GOLD_ETF not stationary

# %% [markdown]
# # Checking stationarity of Equity etf

# %%
def adf_stationarity_test(price):
    indices= ['Test Statistic', 'p-value','no of Lags Used', 'no of Observations Used']
    adf_sta_test=adfuller(price,autolag="AIC")
    print(adf_sta_test)
    result=pd.Series(adf_sta_test[0:4],index=indices)
    for key,value in adf_sta_test[4].items():
        print(key)
        print(value)
        result[f'Critical value({key})']=value
    
    return result
adf_stationarity_test(equity_etf.Close)
# Out:
# (-0.5124798053616574, 0.889558051919623, 0, 180, {'1%': -3.4672111510631, '5%': -2.877734766803841, '10%': -2.575403364197531}, 552.0840952472363)
# 1%
# -3.4672111510631
# 5%
# -2.877734766803841
# 10%
# -2.575403364197531
# Test Statistic              -0.512480
# p-value                      0.889558
# no of Lags Used              0.000000
# no of Observations Used    180.000000
# Critical value(1%)          -3.467211
# Critical value(5%)          -2.877735
# Critical value(10%)         -2.575403
# dtype: float64

# %% [markdown]
# the null hypothesis of the Augmented Duckey Fuller test states that the time series is not stationary.
# p value is 88.95% greater than 5% hence fail to reject null hypothesis hence time series EQUITY_ETF not stationary

# %% [markdown]
# # checking stationary of bitcoin series

# %%
def adf_stationarity_test(price):
    indices= ['Test Statistic', 'p-value','no of Lags Used', 'no of Observations Used']
    adf_sta_test=adfuller(price,autolag="AIC")
    print(adf_sta_test)
    result=pd.Series(adf_sta_test[0:4],index=indices)
    for key,value in adf_sta_test[4].items():
        print(key)
        print(value)
        result[f'Critical value({key})']=value
    
    return result
adf_stationarity_test(bitcoin.Close)
# Out:
# (3.7353690272523625, 1.0, 0, 274, {'1%': -3.4544435065994437, '5%': -2.8721468827772774, '10%': -2.572422013959188}, 3827.3388763265675)
# 1%
# -3.4544435065994437
# 5%
# -2.8721468827772774
# 10%
# -2.572422013959188
# Test Statistic               3.735369
# p-value                      1.000000
# no of Lags Used              0.000000
# no of Observations Used    274.000000
# Critical value(1%)          -3.454444
# Critical value(5%)          -2.872147
# Critical value(10%)         -2.572422
# dtype: float64

# %% [markdown]
# the null hypothesis of the Augmented Duckey Fuller test states that the time series is not stationary.
# p value is 99% greater than 5% hence fail to reject null hypothesis hence time series BITCOIN not stationary

# %% [markdown]
# # Modelling Cointegration

# %%
import statsmodels.api as sm

# %%
gold_etf=gold_etf.resample('D').ffill().reset_index() # filling data for weekends to fit series for analysis

# %%
gold_etf
# Out:
#           Date       Open       High    Low      Close  Adj Close    Volume  \
# 0   2020-04-01  15.070000  15.240000  15.01  15.170000  15.170000  26372200
# 1   2020-04-02  15.390000  15.490000  15.30  15.420000  15.420000  19759000
# 2   2020-04-03  15.470000  15.550000  15.40  15.530000  15.530000  19140500
# 3   2020-04-04  15.470000  15.550000  15.40  15.530000  15.530000  19140500
# 4   2020-04-05  15.470000  15.550000  15.40  15.530000  15.530000  19140500
# ..         ...        ...        ...    ...        ...        ...       ...
# 270 2020-12-27  17.860001  17.930000  17.84  17.920000  17.920000   7495900
# 271 2020-12-28  18.010000  18.080000  17.85  17.870001  17.870001  16733000
# 272 2020-12-29  17.910000  17.990000  17.85  17.910000  17.910000  16025000
# 273 2020-12-30  17.940001  18.059999  17.93  18.049999  18.049999  13599000
# 274 2020-12-31  18.100000  18.129999  18.02  18.129999  18.129999  12471800
#
#      Daily_Returns  Moving_Avg_20_Day
# ...

# %%
equity_etf=equity_etf.resample('D').ffill().reset_index() # filling data for weekends to fit series for analysis

# %%
equity_etf
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-04-01   88.500000   90.000000   86.199997   86.720001   86.720001
# 1   2020-04-02   88.500000   90.000000   86.199997   86.720001   86.720001
# 2   2020-04-03   86.720001   87.440002   84.000000   84.580002   84.580002
# 3   2020-04-04   86.720001   87.440002   84.000000   84.580002   84.580002
# 4   2020-04-05   86.720001   87.440002   84.000000   84.580002   84.580002
# ..         ...         ...         ...         ...         ...         ...
# 270 2020-12-27  142.000000  143.660004  142.000000  143.419998  143.419998
# 271 2020-12-28  143.250000  145.000000  143.000000  144.429993  144.429993
# 272 2020-12-29  144.899994  146.050003  144.330002  144.910004  144.910004
# 273 2020-12-30  145.990005  146.000000  144.360001  145.589996  145.589996
# 274 2020-12-31  145.029999  146.000000  145.029999  145.649994  145.649994
#
#      Volume  Daily_Returns  Moving_Avg_20_Day
# ...

# %%
gold_etf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               275 non-null    datetime64[ns]
#  1   Open               275 non-null    float64
#  2   High               275 non-null    float64
#  3   Low                275 non-null    float64
#  4   Close              275 non-null    float64
#  5   Adj Close          275 non-null    float64
#  6   Volume             275 non-null    int64
#  7   Daily_Returns      275 non-null    float64
#  8   Moving_Avg_20_Day  275 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 19.5 KB

# %%
equity_etf.set_index('Date',inplace=True) # data preparaion for  cointegration

# %%
gold_etf.set_index('Date',inplace=True) # data preparation for co integration

# %%
gold_etf
# Out:
#                  Open       High    Low      Close  Adj Close    Volume  \
# Date
# 2020-04-01  15.070000  15.240000  15.01  15.170000  15.170000  26372200
# 2020-04-02  15.390000  15.490000  15.30  15.420000  15.420000  19759000
# 2020-04-03  15.470000  15.550000  15.40  15.530000  15.530000  19140500
# 2020-04-04  15.470000  15.550000  15.40  15.530000  15.530000  19140500
# 2020-04-05  15.470000  15.550000  15.40  15.530000  15.530000  19140500
# ...               ...        ...    ...        ...        ...       ...
# 2020-12-27  17.860001  17.930000  17.84  17.920000  17.920000   7495900
# 2020-12-28  18.010000  18.080000  17.85  17.870001  17.870001  16733000
# 2020-12-29  17.910000  17.990000  17.85  17.910000  17.910000  16025000
# 2020-12-30  17.940001  18.059999  17.93  18.049999  18.049999  13599000
# 2020-12-31  18.100000  18.129999  18.02  18.129999  18.129999  12471800
#
#             Daily_Returns  Moving_Avg_20_Day
# Date
# ...

# %% [markdown]
# # Engle-Granger Test for Quarter2 data from April to June 2020

# %%
import statsmodels.api as sm
sm.tsa.stattools.coint(equity_etf['2020-04':'2020-06'].Close.values, gold_etf['2020-04':'2020-06'].Close.values, trend='ctt', method='aeg', maxlag=None, autolag='aic', return_results=None)
# Out:
# (-2.2399986491416914,
#  0.836183565655449,
#  array([-4.92541277, -4.30518108, -3.9917815 ]))

# %% [markdown]
# The Null hypothesis is that there is no cointegration, the alternative hypothesis is that there is cointegrating relationship
# as the pvalue=83.61% greater than 5% hence we fail to reject null hypothesis hence there is no cointegration between equity_etf and gold_Etf  for Quarter 2

# %%
sm.tsa.stattools.coint(bitcoin['2020-04':'2020-06'].Close.values, gold_etf['2020-04':'2020-06'].Close.values, trend='ctt', method='aeg', maxlag=None, autolag='aic', return_results=None)
# Out:
# (-3.990591929312587,
#  0.07583854772715205,
#  array([-4.92541277, -4.30518108, -3.9917815 ]))

# %% [markdown]
# The Null hypothesis is that there is no cointegration, the alternative hypothesis is that there is cointegrating relationship as the pvalue=7.58% greater than 5% but if we take 10% singnificance level then hence we can reject  null hypothesis
# hence at verge of accept or reject we have assume there is  cointegration between bitcoin and gold_Etf for Quarter 2

# %%
sm.tsa.stattools.coint(bitcoin['2020-04':'2020-06'].Close.values, equity_etf['2020-04':'2020-06'].Close.values, trend='ctt', method='aeg', maxlag=None, autolag='aic', return_results=None)
# Out:
# (-3.4033591066985434,
#  0.25533891785904694,
#  array([-4.92541277, -4.30518108, -3.9917815 ]))

# %% [markdown]
# The Null hypothesis is that there is no cointegration, the alternative hypothesis is that there is cointegrating relationship as the pvalue=25% greater than 5%  hence we can not  reject  null hypothesis
# there is  no  cointegration between bitcoin and equity_Etf for Quarter 2

# %% [markdown]
# # Are there any cointegrating vectors Q2?
#
#
# gold_etf and bitcoin from Quarter 2
#
#
# found be set of cointrating vector

# %% [markdown]
# # Cointegration analysis for Quarter 3 data from July 2020 To September 2020

# %%
sm.tsa.stattools.coint(equity_etf['2020-07':'2020-09'].Close.values, gold_etf['2020-07':'2020-09'].Close.values, trend='ctt', method='aeg', maxlag=None, autolag='aic', return_results=None)
# Out:
# (-4.638061595025297,
#  0.011953572895767482,
#  array([-4.92277167, -4.30348237, -3.99045988]))

# %% [markdown]
# The Null hypothesis is that there is no cointegration, the alternative hypothesis is that there is cointegrating relationship as the pvalue=1.1% less  than 5% hence
# we  can reject null hypothesis hence there is  cointegration between equity_etf and gold_Etf for Quarter 3

# %%
sm.tsa.stattools.coint(bitcoin['2020-07':'2020-09'].Close.values, gold_etf['2020-07':'2020-09'].Close.values, trend='ctt', method='aeg', maxlag=None, autolag='aic', return_results=None)
# Out:
# (-2.443172402844708,
#  0.7548290681689869,
#  array([-4.92277167, -4.30348237, -3.99045988]))

# %% [markdown]
# The Null hypothesis is that there is no cointegration, the alternative hypothesis is that there is cointegrating relationship as the pvalue=75.48% greater than 5%
# hence we fail to reject null hypothesis hence  there is  no cointegration between bitcoin and gold_Etf for Quarter 3

# %%
sm.tsa.stattools.coint(bitcoin['2020-07':'2020-09'].Close.values, equity_etf['2020-07':'2020-09'].Close.values, trend='ctt', method='aeg', maxlag=None, autolag='aic', return_results=None)
# Out:
# (-2.466833744250269,
#  0.7440788617138094,
#  array([-4.92277167, -4.30348237, -3.99045988]))

# %% [markdown]
# The Null hypothesis is that there is no cointegration, the alternative hypothesis is that there is cointegrating relationship as the pvalue=74.44% greater than 5% but if we take 10% singnificance level then hence we can reject null hypothesis
# hence at verge of accept or reject we have assume there is cointegration between bitcoin and equity_Etf for Quarter 3

# %% [markdown]
# # Are there any cointegrating vectors Q3?
#
#
# equity_etf and gold_etf from Quarter 3
#
#
# found be set of cointrating vector

# %%
# preparing dataframe for Q2 vector error correction model
data_Q2={'bitcoin_Q2':bitcoin['2020-04':'2020-06'].Close.values,'gold_etf_Q2':gold_etf['2020-04':'2020-06'].Close.values}

# %%
data_vecm_Q2=pd.DataFrame(data_Q2)

# %%
data_vecm_Q2
# Out:
#      bitcoin_Q2  gold_etf_Q2
# 0   6606.776367        15.17
# 1   6793.624512        15.42
# 2   6733.387207        15.53
# 3   6867.527344        15.53
# 4   6791.129395        15.53
# ..          ...          ...
# 86  9162.917969        16.93
# 87  9045.390625        16.93
# 88  9143.582031        16.93
# 89  9190.854492        16.93
# 90  9137.993164        16.99
#
# [91 rows x 2 columns]

# %% [markdown]
# # Vector Error Correction model Q2

# %%
from statsmodels.tsa.vector_ar.vecm import VECM
VECM_ETF_Q2 = VECM(endog = data_vecm_Q2[['bitcoin_Q2', 'gold_etf_Q2']], k_ar_diff=6, coint_rank=1, deterministic='cili',
                  seasons=12, first_season=1)
VECM_ETF_Q2_fit = VECM_ETF_Q2.fit()
VECM_ETF_Q2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
# Det. terms outside the coint. relation & lagged endog. parameters for equation bitcoin_Q2
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# season1         -162.8319    117.296     -1.388      0.165    -392.727      67.063
# season2         -267.1121    119.875     -2.228      0.026    -502.063     -32.161
# season3          -50.0911    121.914     -0.411      0.681    -289.038     188.856
# season4         -326.5893    122.464     -2.667      0.008    -566.614     -86.565
# season5         -355.7424    126.382     -2.815      0.005    -603.446    -108.039
# season6          -76.3276    125.255     -0.609      0.542    -321.823     169.168
# season7         -358.7398    129.944     -2.761      0.006    -613.426    -104.054
# season8         -330.9010    134.436     -2.461      0.014    -594.390     -67.412
# ...

# %%
irf = VECM_ETF_Q2_fit.irf(50)
irf.plot(orth=False)

# %% [markdown]
# preparing data fro Q3 vector error correction mdoel

# %%
data_Q3={'equity_etf_Q3':equity_etf['2020-07':'2020-09'].Close.values,'gold_etf_Q3':gold_etf['2020-07':'2020-09'].Close.values}

# %%
data_vecm_Q3=pd.DataFrame(data_Q3)

# %%
data_vecm_Q3
# Out:
#     equity_etf_Q3  gold_etf_Q3
# 0      108.400002    16.920000
# 1      109.300003    16.959999
# 2      109.300003    16.959999
# 3      109.300003    16.959999
# 4      109.300003    16.959999
# ..            ...          ...
# 87     113.309998    17.770000
# 88     113.309998    17.770000
# 89     117.169998    17.940001
# 90     116.930000    18.110001
# 91     117.010002    17.990000
#
# [92 rows x 2 columns]

# %% [markdown]
# # Vector Error Correction model Q3

# %%
from statsmodels.tsa.vector_ar.vecm import VECM

# %%
VECM_ETF_Q3 = VECM(endog = data_vecm_Q3[['equity_etf_Q3', 'gold_etf_Q3']], k_ar_diff=6, coint_rank=1, deterministic='cili',
                  seasons=12, first_season=1)
VECM_ETF_Q3_fit = VECM_ETF_Q3.fit()
VECM_ETF_Q3_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
# Det. terms outside the coint. relation & lagged endog. parameters for equation equity_etf_Q3
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# season1              0.0469      0.461      0.102      0.919      -0.857       0.951
# season2              0.3786      0.481      0.787      0.431      -0.564       1.321
# season3             -0.6742      0.464     -1.454      0.146      -1.583       0.235
# season4              0.0225      0.446      0.050      0.960      -0.852       0.897
# season5              0.5591      0.483      1.157      0.247      -0.388       1.507
# season6              0.4333      0.507      0.855      0.393      -0.560       1.427
# season7              0.7736      0.473      1.635      0.102      -0.154       1.701
# ...

# %%
irf = VECM_ETF_Q3_fit.irf(50)
irf.plot(orth=False)

# %% [markdown]
# # inferences from Vector Error Correction Model
# The loading coefficient (alpha) for GOLD_ETF is  not statistically significant,
# but Equity_ETF  is highly significant and estimated at -0.2011.
# This information means Gold_ETF is  weakly exogenous to Equity_ETF.
# The beta coefficient for Equity_ETF is, again, standardized at 1 for ease of interpretation of the beta coefficients for GOLD_ETF  which is -1.9364 .
# This means a 1% increase in Equity_ETF leads to a 1.93% decrease in Gold_ETF in the long-run and 20% of this correction occurs within a month.
